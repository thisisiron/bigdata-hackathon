# %%
import numpy as np
import pandas as pd

# %%
x_train = pd.read_csv('./training.csv', header=None, encoding='utf-8', names=["date", "office", "arrivals", "quantity"])

# %%
x_train.describe()
# Out:
#                date      arrivals      quantity
# count  3.061286e+06  3.061286e+06  3.061286e+06
# mean   2.017986e+07  1.172022e+01  1.733435e+01
# std    2.571214e+03  7.282712e+00  3.456701e+01
# min    2.017120e+07  0.000000e+00  1.000000e+00
# 25%    2.018023e+07  5.000000e+00  2.000000e+00
# 50%    2.018053e+07  1.200000e+01  6.000000e+00
# 75%    2.018083e+07  1.800000e+01  1.900000e+01
# max    2.018113e+07  2.400000e+01  2.026000e+03

# %%
x_train

# %%
x_train['office'].unique()
# Out:
# array(['가평우체국', '강릉우체국', '강진우체국', '강화우체국', '거제우체국', '거창우체국', '경산우체국',
#        '경주우체국', '고령우체국', '고성우체국', '고창우체국', '고흥우체국', '곡성우체국', '공주우체국',
#        '광명우체국', '광양우체국', '광주우체국', '괴산우체국', '구례우체국', '구리우체국', '구미우체국',
#        '군산우체국', '군위우체국', '군포우체국', '금산우체국', '기장우체국', '김제우체국', '김천우체국',
#        '김포우체국', '김해우체국', '나주우체국', '남원우체국', '남해우체국', '논산우체국', '단양우체국',
#        '달성우체국', '담양우체국', '당진우체국', '대구우체국', '대전우체국', '동래우체국', '동해우체국',
#        '마산우체국', '목포우체국', '무안우체국', '무주우체국', '문경우체국', '밀양우체국', '백령우체국',
#        '보령우체국', '보성우체국', '보은우체국', '봉화우체국', '부산우체국', '부안우체국', '부여우체국',
#        '부천우체국', '부평우체국', '사천우체국', '산청우체국', '삼척우체국', '상주우체국', '서산우체국',
#        '서천우체국', '성남우체국', '성주우체국', '세종우체국', '속초우체국', '수원우체국', '순창우체국',
#        '순천우체국', '시흥우체국', '아산우체국', '안동우체국', '안산우체국', '안성우체국', '안양우체국',
#        '양구우체국', '양산우체국', '양양우체국', '양평우체국', '여수우체국', '여주우체국', '연천우체국',
#        '영광우체국', '영덕우체국', '영동우체국', '영암우체국', '영양우체국', '영월우체국', '영주우체국',
# ...
